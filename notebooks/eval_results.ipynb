# %%
import pandas as pd

# %%
eval_data = pd.read_csv('../eval_data/evaluation_1.csv')
input_q = pd.read_csv('../eval_data/contexts_q.csv')

# %%
eval_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   question           5 non-null      object
#  1   answer             5 non-null      object
#  2   contexts           5 non-null      object
#  3   ground_truth       5 non-null      object
#  4   faithfulness       5 non-null      float64
#  5   answer_relevancy   5 non-null      float64
#  6   context_recall     4 non-null      float64
#  7   context_precision  0 non-null      float64
# dtypes: float64(4), object(4)
# memory usage: 452.0+ bytes

# %%
eval_data.head()
# Out:
#                                             question  \
# 0  ** Quel joueur a le plus grand nombre de rebon...
# 1  ** Quel joueur a le plus grand écart de points...
# 2  ** Quel joueur a le plus grand nombre de minut...
# 3  ** Selon le texte, pourquoi Mike Conley n'étai...
# 4         Que contient la ligne 37 du texte fourni ?
#
#                                               answer  \
# 0  D'après le contexte fourni, seul **Shai Gilgeo...
# 1  D'après le contexte fourni, le tableau ne cont...
# 2  D'après le contexte fourni, la colonne "Min" c...
# 3  Selon le contexte fourni, Mike Conley n'était ...
# 4  La ligne 37 du texte fourni contient le texte ...
#
#                                             contexts  \
# 0  ["27                      TD3            Tripl...
# 1  ['84   Analyse du top 15 des joueurs en nombre...
# 2  ["Dictionnaire des données                    ...
# 3  ['nearly eight straight seasons. If Conley got...
# ...

# %%
eval_data.describe()
# Out:
#        faithfulness  answer_relevancy  context_recall  context_precision
# count      5.000000          5.000000            4.00                0.0
# mean       0.696429          0.336203            0.25                NaN
# std        0.252889          0.461206            0.50                NaN
# min        0.333333          0.000000            0.00                NaN
# 25%        0.625000          0.000000            0.00                NaN
# 50%        0.666667          0.000000            0.00                NaN
# 75%        0.857143          0.801145            0.25                NaN
# max        1.000000          0.879871            1.00                NaN

# %%
print('CHUNK UTILISE')
print(input_q['context_question'][0])
print('QUESTION POSEE')
print(eval_data['question'][0])
print('CHUNKS RECUPERER PAR LE RAG')
print(eval_data['contexts'][0])
print('REPONSE FOURNI PAR LE LLM')
print(eval_data['answer'][0])
print('REPONSE ATTENDU')
print(eval_data['ground_truth'][0])
# Out:
# CHUNK UTILISE
# 119        Kristaps Porziņģis   BOS   29  42  30  12  28.8   819  277   575  48.3       105  252  41.2  160  197  80.9    67   214   286   88   55   29   63  118  1520    6    0   4.1   116.2   110.3     5.8  11.3    1.64       10.8    5.4   16.3    11       6.6  57.2  61.8  25.3   99.83  13.2  2528 NaN NaN NaN NaN NaN NaN NaN NaN
# 120           Duncan Robinson   MIA   31  74  30  44  24.1   814  289   666  43.7       192  481  39.3   44   52  88.7    15   148   170  178   89   37    7  133  1332    0    0   0.9   110.1   109.9     0.2  14.8    2.05       18.6      1    8.4   4.7       9.1  58.1  59.5  18.7   97.68   7.8  3661 NaN NaN NaN NaN NaN NaN NaN NaN
# ...

# %%
n = 1
print('CHUNK UTILISE')
print(input_q['context_question'][n])
print('QUESTION POSEE')
print(eval_data['question'][n])
print('CHUNKS RECUPERER PAR LE RAG')
print(eval_data['contexts'][n])
print('REPONSE FOURNI PAR LE LLM')
print(eval_data['answer'][n])
print('REPONSE ATTENDU')
print(eval_data['ground_truth'][n])
# Out:
# CHUNK UTILISE
# 539              Anton Watson   NYK   24   9   5   4   2.5     8    4     9  44.4         0    1     0    0    0     0     1     2     3    2    2    1    0    3    15    0    0    -1   103.9   119.2   -15.3  12.5       1       15.4      5   11.8   8.1      15.4  44.4  44.4  19.3  111.52   3.3    51 NaN NaN NaN NaN NaN NaN NaN NaN
# 540           Phillip Wheeler   PHI   23   5   0   5   8.9     8    3    21  14.3         0   10     0    2    2   100     2     6     8    2    1    1    2    1    29    0    0   2.6     110    96.6    13.4   6.5       2          8    3.6   12.5   7.7         4  14.3  18.3  22.1   96.76  -0.5    90 NaN NaN NaN NaN NaN NaN NaN NaN
# ...
